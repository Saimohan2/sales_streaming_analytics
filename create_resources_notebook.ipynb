# %%
from databricks.connect import DatabricksSession

spark = DatabricksSession.builder.getOrCreate()

# %%
#create schemas

# spark.sql("create schema sales_streaming_dev.slv;")
# spark.sql("create schema sales_streaming_dev.gld;")
# spark.sql("create schema sales_streaming_test.brz;")
# spark.sql("create schema sales_streaming_test.slv;")
# spark.sql("create schema sales_streaming_test.gld;")
# spark.sql("create schema sales_streaming_prod.brz;")
# spark.sql("create schema sales_streaming_prod.slv;")
# spark.sql("create schema sales_streaming_prod.gld;")
# Out:
# DataFrame[]
